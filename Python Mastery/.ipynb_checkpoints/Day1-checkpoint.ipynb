# %%
for i in range(5) :
   print("Iteration", i)
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4

# %%
name = "Riyan"
print(f"Welcome, {name}! Jupyter is ready for your AI & data journey..")
# Out:
# Welcome, Riyan! Jupyter is ready for your AI & data journey..
